# %%
def celsius_to_fahrenheit(celsius):
    fahrenheit = celsius * 9/5 + 32
    print (f"{celsius}°C = {fahrenheit}°F")

c = float(input("Digite a temperatura em celsius:"))
celsius_to_fahrenheit(c)
# Out:
# Digite a temperatura em celsius: 37.5
# 37.5°C = 99.5°F
