# %% [markdown]
# ![Algoritmos e Estrutura de Dados I](AED1_banner.jpg)

# %% [markdown]
# ## <font color='blue'>Algoritmos e Estrutura de Dados 1 </font>
# ### <font color='blue'>Aula 14 - Continuação sobre Funções</font>

# %%
# Versão da Linguagem Python
from platform import python_version
print('Versão da Linguagem Python Usada Neste Jupyter Notebook:', python_version())
# Out:
# Versão da Linguagem Python Usada Neste Jupyter Notebook: 3.12.7

# %%
def potencia(base, expoente = 2):
    """" Essa função faz o calculo de potência, se inserido somente um número, será elevado ao quadrado, caso contrário, será elevada ao segundo paramentro
    Parametros:
    base = número a ser levado à potencia (float)
    expoente = número da potência (int)
    Retorno = O resultado da potência (float)"""
   
    return base ** expoente

# %%
print(potencia(3))
print(potencia(3,4))
# Out:
# 9
# 81

# %%
def soma(*args):
    soma = 0
    for i in args:
        soma += i
    return soma

# %%
print (soma(1,2,4,500))
# Out:
# 517

# %%
def cores_favoritas(**kwargs):
    for nome in kwargs:
        print (f"{nome} gosta da cor {kwargs[nome]}")
print ("1 ")
cores_favoritas(ana = "vermelho", marcelo = "amarelo"
# Out:
#   Cell In[56], line 5
#     cores_favoritas(ana = "vermelho", marcelo = "amarelo"
#                                                          ^
# SyntaxError: incomplete input

# %%
def central_respostas(*args):
    if args:
        print(f"{len(args)} mensagens recebidas.")
        [print(f"Mensagem {i+1} recebida: {f}") for i, f in enumerate(args)]
    else:
        print("Nenhuma mensagem recebida. Por favor, tente novamente.")

central_respostas(
    "Gostaria de saber o status do meu pedido.",
    "Também quero alterar meu endereço de entrega."
)

central_respostas()
# Out:
# 2 mensagens recebidas.
# Mensagem 1 recebida: Gostaria de saber o status do meu pedido.
# Mensagem 2 recebida: Também quero alterar meu endereço de entrega.
# Nenhuma mensagem recebida. Por favor, tente novamente.

# %%
def central_respostas(*args):
    if args:
        qtd = len(args)
        print (qtd, "Mensagem(ns) recebidas.")
        i = 1
        for msg in args:
            print(f"Mensagem {i} redebida: {msg}")
            i = i + 1
    else:
        print ("não tem frases")

# %%
central_respostas(
    "Gostaria de saber o status do meu pedido.",
    "Também quero alterar meu endereço de entrega."
)

central_respostas()
# Out:
# 2 Mensagem(ns) recebidas.
# Mensagem 1 redebida: Gostaria de saber o status do meu pedido.
# Mensagem 2 redebida: Também quero alterar meu endereço de entrega.
# não tem frases

# %%
import random

# %%
for i in range(6):
 print(random.uniform(0, 100))
# Out:
# 91.6429761970066
# 48.965389172955696
# 5.426659431767478
# 98.91046835018244
# 40.15447077391211
# 50.422402788629164

# %%
for i in range(6):
 print(random.randint(0, 100))
# Out:
# 76
# 39
# 64
# 43
# 12
# 94

# %%
for i in range(6):
 print(random.random())
# Out:
# 0.9852442403179749
# 0.6368358059078941
# 0.09735646890199623
# 0.28874496890736745
# 0.5816754078762961
# 0.25142447700737514

# %%
from random import choice

escolha = ["pedra", "papel", "tesoura"]
print (choice(escolha))
# Out:
# pedra

# %%
from random import choice

# Lista de opções
escolha = ["pedra", "papel", "tesoura"]

# Pergunta o nome do jogador
nome = input("Digite seu nome: ")

# Contadores
vitorias_jogador = 0
vitorias_computador = 0
empates = 0

while True:
    jogador = input(f"\n{nome}, escolha pedra, papel ou tesoura: ").lower()
    if jogador not in escolha:
        print("Opção inválida. Tente novamente.")
        continue

    computador = choice(escolha)
    print(f"O computador escolheu: {computador}")

    # Determina o resultado
    if jogador == computador:
        print("Empate!")
        empates += 1
    elif (jogador == "pedra" and computador == "tesoura") or \
         (jogador == "papel" and computador == "pedra") or \
         (jogador == "tesoura" and computador == "papel"):
        print(f"{nome} venceu!")
        vitorias_jogador += 1
    else:
        print("Computador venceu!")
        vitorias_computador += 1

    continuar = input("\nDeseja jogar novamente? (s/n): ").lower()
    if continuar != 's':
        break

# Resultado final
print("\n=== RESULTADO FINAL ===")
print(f"Vitórias de {nome}....: {vitorias_jogador}")
print(f"Vitórias do Computador: {vitorias_computador}")
print(f"Empates...............: {empates}")

# Campeão
if vitorias_jogador > vitorias_computador:
    print(f"\n{nome} foi o grande Campeão!")
elif vitorias_jogador < vitorias_computador:
    print("\nO Computador foi o grande Campeão!")
else:
    print("\nO jogo terminou empatado!")
# Out:
# Digite seu nome:  paulo
#
# paulo, escolha pedra, papel ou tesoura:  pedra
# O computador escolheu: pedra
# Empate!
# Deseja jogar novamente? (s/n):  s
#
# paulo, escolha pedra, papel ou tesoura:  pedra
# O computador escolheu: papel
# Computador venceu!
# Deseja jogar novamente? (s/n):  n
# === RESULTADO FINAL ===
# Vitórias de paulo....: 0
# Vitórias do Computador: 1
# Empates...............: 1
#
# O Computador foi o grande Campeão!

# %%
# !pip install arrow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: arrow in c:\programdata\anaconda3\lib\site-packages (1.2.3)
# Requirement already satisfied: python-dateutil>=2.7.0 in c:\programdata\anaconda3\lib\site-packages (from arrow) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.7.0->arrow) (1.16.0)

# %% [markdown]
# ## Funções

# %%
# Função para somar números
def addNum(n1, n2):
    print("Primeiro número: " + str(n1))
    print("Segundo número: " + str(n2))
    print("Soma: ", n1 + n2)

# %%
# Chamando a função e passando parâmetros
addNum(4, 7)

# %%
# Chamando a função e passando parâmetros
addNum(45, 3)

# %%
# Funções com número variável de argumentos
# É muito comum encontrar como nome dessa variável: *args
def printVarInfo( arg1, *vartuple ):
    
   # Imprimindo o valor do primeiro argumento
    print ("O parâmetro passado foi: ", arg1)
   
   # Imprimindo o valor do segundo argumento 
    for item in vartuple:
        print ("O parâmetro passado foi: ", item)
    return;

# %%
# Fazendo chamada à função usando apenas 1 argumento
printVarInfo(10)

# %%
printVarInfo('Chocolate', 'Morango')

# %%
printVarInfo('PyPRO', 'Fatec', 'CDN', 'Ciência de Dados')

# %% [markdown]
# ## Criando Funções Usando Outras Funções
#
# https://pypi.org/

# %%
import math

# Verificando se um número é primo
def numPrimo(num):
    if (num % 2) == 0 and num > 2: 
        return "Este número não é primo"
    for i in range(3, int(math.sqrt(num)) + 1, 2):
        if (num % i) == 0:
            return "Este número não é primo"
    return "Este número é primo"

# %%
numPrimo(541)

# %%
numPrimo(2)

# %%
numPrimo(6)

# %%
caixa_baixa = "Este Texto Deveria Estar Todo Em LowerCase"

# %%
def lowercase(text):
    return text.lower()

# %%
string_caixa_baixa = lowercase(caixa_baixa)

# %%
string_caixa_baixa

# %% [markdown]
# ## Fazendo Split dos Dados

# %%
# Fazendo split dos dados
def split_string_palavras(text):
    return text.split(" ")

# %%
texto = "Esta função será bastante útil para separar grandes volumes de dados."

# %%
# Isso divide a string em uma lista de palavras
print(split_string_palavras(texto))

# %%
# Podemos atribuir o output de uma função para uma variável
token = split_string_palavras(texto)

# %%
token

# %%
# Fazendo split dos dados
def split_string_letras(text):
    texto = text.upper()
    for letra in texto:
        print(letra)

# %%
split_string_letras(texto)

# %% [markdown]
# ## Expressão ou Função Lambda

# %%
# Definindo uma função - 3 linhas de código
def potencia(num):
    resultado = num ** 2
    return resultado

# %%
potencia(5)

# %%
# Definindo uma função - 1 linha de código
def potencia(num): return num ** 2

# %%
potencia(5)

# %%
# Definindo uma expressão lambda (função anônima)
potencia = lambda num: num ** 2

# %%
potencia(5)

# %%
# Lembre: operadores de comparação retornam boolean: true or false
par = lambda x: x%2==0

# %%
par(3)

# %%
primeira_letra = lambda s: s[0]

# %%
primeira_letra("Fatec Votorantim")

# %%
reverso = lambda s: s[::-1]

# %%
reverso("Fatec Votorantim")

# %%
adicao = lambda x,y : x+y

# %%
adicao(3, 5)

# %% [markdown]
# ## Exercícios

# %% [markdown]
# 1. Faça um programa que use a função valorPagamento para determinar o valor a ser pago por uma prestação de uma conta. O programa deverá solicitar ao usuário o valor da prestação e o número de dias em atraso e passar estes valores para a função valorPagamento, que calculará o valor a ser pago e devolverá este valor ao programa que a chamou. O programa deverá então exibir o valor a ser pago na tela. Após a execução o programa deverá voltar a pedir outro valor de prestação e assim continuar até que seja informado um valor igual a zero para a prestação. Neste momento o programa deverá ser encerrado, exibindo o relatório do dia, que conterá a quantidade e o valor total de prestações pagas no dia. O cálculo do valor a ser pago é feito da seguinte forma. Para pagamentos sem atraso, cobrar o valor da prestação. Quando houver atraso, cobrar 3% de multa, mais 0,1% de juros por dia de atraso

# %%
def valorPagamento(valor, diasAtraso):
    if (valor < 0):
        return None
    if (diasAtraso > 0):
        multa = valor * 0.03
        adicionalAtraso = valor * (diasAtraso * 0.01)
        return valor + multa + adicionalAtraso
    else:
        return valor

# %%
# Entrada de Dados
valor = 1
while (valor != 0):
    valor = float(input('Informe o valor da prestação: '))
    if (valor != 0):
        diasAtraso = int(input('Informe a qtd de dias de atraso: '))
        print(f"Valor a ser pago: {valorPagamento(valor, diasAtraso):.2f}")

# %% [markdown]
# 2. Embaralha palavra. Construa uma função que receba uma string como parâmetro e devolva outra string com os carateres embaralhados. Por exemplo: se função receber a palavra python, pode retornar npthyo, ophtyn ou qualquer outra combinação possível, de forma aleatória. Padronize em sua função que todos os caracteres serão devolvidos em caixa alta ou caixa baixa, independentemente de como foram digitados

# %%
import random

def embaralhaPalavra(palavra):
    arrayPos = []
    tamanho = len(palavra)
    for i in range(0, tamanho):
        arrayPos.append(i)
    for i in range(0, tamanho):
        pos1 = random.randint(0, tamanho - 1)
        pos2 = random.randint(0, tamanho - 1)

        aux = arrayPos[pos1]
        arrayPos[pos1] = arrayPos[pos2]
        arrayPos[pos2] = aux

    retorno = ''
    for i in arrayPos:
        retorno += palavra[i]

    return retorno.upper()

# %%
# Fluxo Principal
palavra = input('Informe uma palavra: ')
print(embaralhaPalavra(palavra))

# %% [markdown]
# ## Fim da Aula 14
